# %% [markdown]
# # EDA and ML Insights on Youtube Trending Dataset

# %% [markdown]
# <h1 style="font-family:COMIC SANS ;text-align:left;background-color:salmon"><b><u>IMPORTING PACKAGES</u></b></h1>

# %%
import numpy as np   
import pandas as pd  
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
import json
warnings.filterwarnings('ignore') # To supress warnings
sns.set(style="darkgrid") # set the background for the graphs
pd.set_option('display.float_format', lambda x: '%.3f' % x)

from collections import Counter
import datetime
import wordcloud

# %% [markdown]
# <h1 style="font-family:COMIC SANS ;text-align:left;background-color:salmon"><b><u>📖 READING DATA 📖</u></b></h1>

# %%
#Reading Dataset of trends in india
path_india='../input/youtube-trending-video-dataset/IN_youtube_trending_data.csv'
df_india = pd.read_csv(path_india)
#df_inda.loc[publishedAt]

# %% [markdown]
# <h1 style="font-family:COMIC SANS ;text-align:left;background-color:salmon"><b><u>👀  EXPLORING DATASET 👀 </u></b></h1>

# %% [markdown]
# <div class ="alert alert-block alert-info">
# <font size=4><b><i> We start with inspecting the dataset and record observations:</i></b></font><br>
#      1.Check the correctness the dataset ?.<br>
#      2.Check for attributes/columns,check if headers are clean<br>
#      3.Number of rows and columns in data set (Dimension of dataset) <br>
#      4.What are the data types of the data, and how many columns are numeric?<br>
#      5.Are the datatype correct ?

# %%
#This function returns the first 5 rows for the dataset
df_india.head()
# Out:
#       video_id                                              title  \
# 0  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1  x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2  KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3  UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4  WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-12T04:31:41Z  UCGqvJPRcv7aVFun-eTsatcA    FoxStarHindi          24
# 1  2020-08-11T09:00:11Z  UCm9SZAl03Rev9sFwloCdz1g  Rehaan Records          10
# 2  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg  Diljit Dosanjh          10
# 3  2020-08-10T05:30:49Z  UCq-Fj5jknLsUf-MWSy4_brA        T-Series          10
# 4  2020-08-11T05:30:13Z  UCye6Oz0mg46S362LwARGVcA   VYRLOriginals          10
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  sadak|sadak 2|mahesh bhatt|vishesh films|pooja...
# 1  2020-08-12T00:00:00Z                                             [None]
# 2  2020-08-12T00:00:00Z  clash diljit dosanjh|diljit dosanjh|diljit dos...
# 3  2020-08-12T00:00:00Z  hindi songs|2020 hindi songs|2020 new songs|t-...
# 4  2020-08-12T00:00:00Z  VYRL Original|Mohsin Khan|Shivangi Joshi|Payal...
#
#    view_count   likes  dislikes  comment_count  \
# 0     9885899  224925   3979409         350210
# 1    11308046  655450     33242         405146
# 2     9140911  296533      6179          30058
# 3    23564512  743931     84162         136942
# 4     6783649  268817      8798          22984
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/Iot0eF6EoNA/default.jpg              False
# 1  https://i.ytimg.com/vi/x-KbnJ9fvJc/default.jpg              False
# 2  https://i.ytimg.com/vi/KX06ksuS6Xo/default.jpg              False
# 3  https://i.ytimg.com/vi/UsMRgnTcchY/default.jpg              False
# 4  https://i.ytimg.com/vi/WNSEXJJhKTU/default.jpg              False
#
#    ratings_disabled                                        description
# 0             False  Three Streams. Three Stories. One Journey. Sta...
# 1             False  Singer/Lyrics: Karan Aujla Feat Tania Music/ D...
# 2             False  CLASH official music video performed by DILJIT...
# 3             False  Gulshan Kumar and T-Series presents Bhushan Ku...
# 4             False  VYRL Originals brings to you ‘Baarish’ - the b...

# %%
#displays last 5 rows
df_india.tail()
# Out:
#            video_id                                              title  \
# 128909  T5-Nr59vrZM  Current Affairs Revision | January to 15 May |...
# 128910  uWKdqqdgYQE          Life mein Lafde lag gaye | This is Sumesh
# 128911  XQcg2MHXZF8  Mera Intkam Dekhegi | Waqt Sabka Badalta Hai |...
# 128912  KY-q3Yihapg       Tom&Jerry 🥰sayoo&anvi #sangeethkumar #shorts
# 128913  VzOUwM4Wf1Q  Short Highlights | Pakistan vs West Indies | 1...
#
#                  publishedAt                 channelId  \
# 128909  2022-06-12T01:28:21Z  UCLuBF4Xr1-BIpcpFFm7zp7w
# 128910  2022-06-10T12:30:11Z  UCB7M7vqKZ2q2oX6nL_oOmUg
# 128911  2022-06-10T01:30:10Z  UC2EIKl_8jcEkE7OqOo7WFRw
# 128912  2022-06-11T04:30:05Z  UCdce_0JccaDtpuv5x9Gjdyw
# 128913  2022-06-08T21:32:34Z  UCiWrjBhlICf_L_RK5y6Vrxw
#
#                    channelTitle  categoryId         trending_date  \
# 128909  UTKARSH CLASSES JODHPUR          27  2022-06-13T00:00:00Z
# 128910           This is sumesh          23  2022-06-13T00:00:00Z
# 128911         Love Me Creation          24  2022-06-13T00:00:00Z
# 128912           Sangeeth Kumar          22  2022-06-13T00:00:00Z
# 128913         Pakistan Cricket          17  2022-06-13T00:00:00Z
#
#                                                      tags  view_count  likes  \
# 128909  utkarsh classes jodhpur|utkarsh classes|utkars...      638024  73523
# 128910  this is sumesh new video|sumesh new video|new ...      175016  15812
# 128911  love me creation|thukrakemerapyaar|thukrake|re...      295374   1524
# 128912                                             [None]     1079878  97307
# 128913  Full Highlights|Pakistan|West Indies|Pakistan ...     1065703  26985
#
#         dislikes  comment_count  \
# 128909         0           1101
# 128910         0            461
# 128911         0             77
# 128912         0            301
# 128913         0            901
#
#                                         thumbnail_link  comments_disabled  \
# 128909  https://i.ytimg.com/vi/T5-Nr59vrZM/default.jpg              False
# 128910  https://i.ytimg.com/vi/uWKdqqdgYQE/default.jpg              False
# 128911  https://i.ytimg.com/vi/XQcg2MHXZF8/default.jpg              False
# 128912  https://i.ytimg.com/vi/KY-q3Yihapg/default.jpg              False
# 128913  https://i.ytimg.com/vi/VzOUwM4Wf1Q/default.jpg              False
#
#         ratings_disabled                                        description
# 128909             False  Current Affairs Revision | January to 15 May |...
# 128910             False  Muuchstac Skin Lightening Oil Combo:-Amazon : ...
# 128911             False  Mera Intkam Dekhegi | Waqt Sabka Badalta Hai |...
# 128912             False  #Sangeeth Kumar With familyOur Second Channel🥰...
# 128913             False  Short Highlights | Pakistan vs West Indies | 1...

# %%
print ("Rows     : " , df_india.shape[0]) #Displays numbers of rows .
print ("Columns  : " , df_india.shape[1]) # and column our dataset contains.
print ("\nFeatures : \n", df_india.columns.tolist())#displays column names
print ("\nMissing values :  ", df_india.isnull().sum().values.sum())   #find missing values
print ("\nUnique values :  \n", df_india.nunique())  # Count distinct observations
# Out:
# Rows     :  128914
# Columns  :  16
#
# Features :
#  ['video_id', 'title', 'publishedAt', 'channelId', 'channelTitle', 'categoryId', 'trending_date', 'tags', 'view_count', 'likes', 'dislikes', 'comment_count', 'thumbnail_link', 'comments_disabled', 'ratings_disabled', 'description']
#
# Missing values :   10210
#
# Unique values :
#  video_id              38034
# title                 38534
# publishedAt           37660
# channelId              3443
# channelTitle           3548
# categoryId               15
# trending_date           655
# tags                  24584
# view_count           126142
# likes                 90874
# dislikes              17039
# comment_count         25412
# thumbnail_link        38035
# comments_disabled         2
# ratings_disabled          2
# description           33293
# dtype: int64

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔There are 128127 rows and 16 columns in  the dataset<br>
#  ✔Qualitative Variables are title,channelId,channelTitle,categoryId are most important attributes for our analysis<br>
#  ✔Quantitative Variables are PublishedAt,trending_date,view_count,likes,
#     dislikes,comment_count<br>
# </div>

# %%
# Displays columns and datatype .
df_india.dtypes
# Out:
# video_id             object
# title                object
# publishedAt          object
# channelId            object
# channelTitle         object
# categoryId            int64
# trending_date        object
# tags                 object
# view_count            int64
# likes                 int64
# dislikes              int64
# comment_count         int64
# thumbnail_link       object
# comments_disabled      bool
# ratings_disabled       bool
# description          object
# dtype: object

# %%
#This method prints information about a dataset including the index dtype and columns,
#non-null values and memory usage.
df_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128914 entries, 0 to 128913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           128914 non-null  object
#  1   title              128914 non-null  object
#  2   publishedAt        128914 non-null  object
#  3   channelId          128914 non-null  object
#  4   channelTitle       128913 non-null  object
#  5   categoryId         128914 non-null  int64
#  6   trending_date      128914 non-null  object
#  7   tags               128914 non-null  object
#  8   view_count         128914 non-null  int64
#  9   likes              128914 non-null  int64
#  10  dislikes           128914 non-null  int64
#  11  comment_count      128914 non-null  int64
#  12  thumbnail_link     128914 non-null  object
#  13  comments_disabled  128914 non-null  bool
#  14  ratings_disabled   128914 non-null  bool
#  15  description        118705 non-null  object
# dtypes: bool(2), int64(5), object(9)
# memory usage: 14.0+ MB

# %% [markdown]
# <h1 style="font-family:COMIC SANS ;text-align:left;background-color:salmon"><b> CLEANING THE DATASET</b></h1>

# %% [markdown]
# # Dealing with Missing Values

# %%
df_india.isna().sum()
# Out:
# video_id                 0
# title                    0
# publishedAt              0
# channelId                0
# channelTitle             1
# categoryId               0
# trending_date            0
# tags                     0
# view_count               0
# likes                    0
# dislikes                 0
# comment_count            0
# thumbnail_link           0
# comments_disabled        0
# ratings_disabled         0
# description          10209
# dtype: int64

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
# ✔In India dataset , description is missing from 10076 observations and channeltitle is missing only 1 obeservation.

# %%
# Since description is missing from alot of videos, we can replace it with an empty string
df_india.description.fillna('',inplace=True) 
df_india.dropna(axis=0,inplace=True)
df_india.isna().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# likes                0
# dislikes             0
# comment_count        0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          0
# dtype: int64

# %% [markdown]
# # Getting category from the category file

# %%
#we need id and title from this file which are under items tag and snippet contain title
# with open("../input/youtube-trending-video-dataset/IN_category_id.json") as f:
#     categories = json.load(f)["items"]
# cat_dict = {}
# category=[]
# for cat in categories:
#     category.append([cat["id"],cat["snippet"]["title"]])
with open("../input/youtube-trending-video-dataset/IN_category_id.json") as f:
    categories = json.load(f)["items"]

cat_dict = {}

for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
    
df_india['category_name'] = df_india['categoryId'].map(cat_dict)

# %%
df_india.head(5)
# Out:
#       video_id                                              title  \
# 0  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1  x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2  KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3  UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4  WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-12T04:31:41Z  UCGqvJPRcv7aVFun-eTsatcA    FoxStarHindi          24
# 1  2020-08-11T09:00:11Z  UCm9SZAl03Rev9sFwloCdz1g  Rehaan Records          10
# 2  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg  Diljit Dosanjh          10
# 3  2020-08-10T05:30:49Z  UCq-Fj5jknLsUf-MWSy4_brA        T-Series          10
# 4  2020-08-11T05:30:13Z  UCye6Oz0mg46S362LwARGVcA   VYRLOriginals          10
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  sadak|sadak 2|mahesh bhatt|vishesh films|pooja...
# 1  2020-08-12T00:00:00Z                                             [None]
# 2  2020-08-12T00:00:00Z  clash diljit dosanjh|diljit dosanjh|diljit dos...
# 3  2020-08-12T00:00:00Z  hindi songs|2020 hindi songs|2020 new songs|t-...
# 4  2020-08-12T00:00:00Z  VYRL Original|Mohsin Khan|Shivangi Joshi|Payal...
#
#    view_count   likes  dislikes  comment_count  \
# 0     9885899  224925   3979409         350210
# 1    11308046  655450     33242         405146
# 2     9140911  296533      6179          30058
# 3    23564512  743931     84162         136942
# 4     6783649  268817      8798          22984
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/Iot0eF6EoNA/default.jpg              False
# 1  https://i.ytimg.com/vi/x-KbnJ9fvJc/default.jpg              False
# 2  https://i.ytimg.com/vi/KX06ksuS6Xo/default.jpg              False
# 3  https://i.ytimg.com/vi/UsMRgnTcchY/default.jpg              False
# 4  https://i.ytimg.com/vi/WNSEXJJhKTU/default.jpg              False
#
#    ratings_disabled                                        description  \
# 0             False  Three Streams. Three Stories. One Journey. Sta...
# 1             False  Singer/Lyrics: Karan Aujla Feat Tania Music/ D...
# 2             False  CLASH official music video performed by DILJIT...
# 3             False  Gulshan Kumar and T-Series presents Bhushan Ku...
# 4             False  VYRL Originals brings to you ‘Baarish’ - the b...
#
#    category_name
# 0  Entertainment
# 1          Music
# 2          Music
# 3          Music
# 4          Music

# %%
df_india.isna().sum()
# Out:
# video_id              0
# title                 0
# publishedAt           0
# channelId             0
# channelTitle          0
# categoryId            0
# trending_date         0
# tags                  0
# view_count            0
# likes                 0
# dislikes              0
# comment_count         0
# thumbnail_link        0
# comments_disabled     0
# ratings_disabled      0
# description           0
# category_name        66
# dtype: int64

# %%
# drop rows containing null value for category_name
df_india.dropna(axis=0,inplace=True)

# %%
df_india.isna().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# likes                0
# dislikes             0
# comment_count        0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          0
# category_name        0
# dtype: int64

# %%
df_india.shape
# Out:
# (128847, 17)

# %% [markdown]
# ## Removing columns which are not needed for analysis

# %%
df_india.drop(['video_id','channelId','categoryId','thumbnail_link'],axis=1,inplace=True)
df_india.head(5)
df_india.shape
# Out:
# (128847, 13)

# %%
df_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128847 entries, 0 to 128913
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title              128847 non-null  object
#  1   publishedAt        128847 non-null  object
#  2   channelTitle       128847 non-null  object
#  3   trending_date      128847 non-null  object
#  4   tags               128847 non-null  object
#  5   view_count         128847 non-null  int64
#  6   likes              128847 non-null  int64
#  7   dislikes           128847 non-null  int64
#  8   comment_count      128847 non-null  int64
#  9   comments_disabled  128847 non-null  bool
#  10  ratings_disabled   128847 non-null  bool
#  11  description        128847 non-null  object
#  12  category_name      128847 non-null  object
# dtypes: bool(2), int64(4), object(7)
# memory usage: 12.0+ MB

# %% [markdown]
# <h1 style="font-family:COMIC SANS ;text-align:left;background-color:salmon"><b>📄 Exploratory Data Analysis📄</b></h1>

# %% [markdown]
# ## Descriptive Statistics

# %%
#displays only numeric variables
df_india.describe()
# Out:
#          view_count        likes     dislikes  comment_count
# count    128847.000   128847.000   128847.000     128847.000
# mean    3105109.233   164287.829     4549.846      10711.203
# std     7626150.755   446239.928   100496.571      90883.623
# min           0.000        0.000        0.000          0.000
# 25%      443070.500    16656.000        0.000        480.000
# 50%     1065745.000    47443.000      671.000       1507.000
# 75%     2696150.000   135962.000     2470.000       5067.500
# max   264407389.000 16115240.000 12341474.000    6738565.000

# %%
# displays all varaibles
df_india.describe(exclude='number')
# Out:
#                         title           publishedAt      channelTitle  \
# count                  128847                128847            128847
# unique                  38516                 37643              3544
# top     #shorts #strugglejeet  2021-06-04T18:15:01Z  Vijay Television
# freq                       41                    20              1670
#
#                trending_date    tags comments_disabled ratings_disabled  \
# count                 128847  128847            128847           128847
# unique                   655   24575                 2                2
# top     2021-03-02T00:00:00Z  [None]             False            False
# freq                     398   22562            127754           127772
#
#        description  category_name
# count       128847         128847
# unique       33276             14
# top                 Entertainment
# freq         10209          50295

# %%
df_india.publishedAt.min()
# Out:
# '2020-07-23T11:30:37Z'

# %%
df_india.publishedAt.max()
# Out:
# '2022-06-13T02:30:13Z'

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔The dataset contains observation of videos published from 23 July 2020 to 10 June 2022.<br>
#  ✔ There are 14 different categories in dataset <br>
#  ✔ There are 3536 unique channels.<br>
#   ✔There are 38358 unique videos.

# %% [markdown]
# # Which is the most watched video?

# %%
# find the video which has maximum view count.
df_india[df_india['view_count'].isin([df_india.view_count.max()])]
# Out:
#                                   title           publishedAt channelTitle  \
# 52057  BTS (방탄소년단) 'Butter' Official MV  2021-05-21T03:46:13Z  HYBE LABELS
#
#               trending_date                             tags  view_count  \
# 52057  2021-05-30T00:00:00Z  BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   264407389
#
#           likes  dislikes  comment_count  comments_disabled  ratings_disabled  \
# 52057  16021542    150990        6738565              False             False
#
#                                              description category_name
# 52057  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...         Music

# %% [markdown]
# # Which are the top 10 most watched trending videos?

# %%
# get top 30 most watched videos
top30viewed=df_india.sort_values(by=['view_count'],ascending=False).head(40)
# we just want the first string from the title and title is pipe separated
top30viewed.title=top30viewed.title.str.split(pat='|').apply(lambda x: x[0])
#top30viewed.reset_index()
sns.catplot(data=top30viewed, x='title', y='view_count',kind='bar',palette='cool_r' ,ci=None, legend_out=False,aspect =2)

plt.ylabel('Number of views')
plt.xlabel('Title')
plt.title('TOP 10 MOST WATCHED VIDEOS',fontsize=30)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔The most watched videos are BTS music videos Butter and Dynamite followed by Filhaal 2 music video.<br>
#  ✔ Most videos in top 10 are either music videos or movie trailers with one shorts video <br>

# %% [markdown]
# ## <a name="corr"></a>Correlation between dataset variables
# Now let's see how the dataset variables are [correlated](https://www.mathsisfun.com/data/correlation.html) with each other: for example, we would like to see how views and likes are correlated, meaning do views and likes increase and decrease together (positive correlation)? Does one of them increase when the other decrease and vice versa (negative correlation)? Or are they not correlated?
#
# Correlation is represented as a value between `-1` and `+1` where `+1` denotes the highest positive correlation, `-1` denotes the highest negative correlation, and `0` denotes that there is no correlation.
#
# Let's see the correlation table between our dataset variables (numerical and boolean variables only)

# %%
h_labels = [x.replace('_', ' ').title() for x in 
            list(df_india.select_dtypes(include=['number', 'bool']).columns.values)]

fig, ax = plt.subplots(figsize=(10,6))
_ = sns.heatmap(df_india.corr(), annot=True, xticklabels=h_labels, yticklabels=h_labels, cmap=sns.cubehelix_palette(as_cmap=True), ax=ax)

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔The features which are most correlated is likes and view count with a value of 0.81.<br>
#  ✔ We can develop a regression model to predict views of a video from its likes <br>

# %% [markdown]
# # View Count vs Likes Plot

# %%
fig, ax = plt.subplots(figsize=(10,6))
_ = plt.scatter(x=df_india['view_count'], y=df_india['likes'], edgecolors="#000000", linewidths=0.5)
_ = ax.set(xlabel="Views", ylabel="Likes")
_ = plt.title('LIKES VS VIEW COUNT',fontsize=30)

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔The likes and views of a video have a linear relationship so we can try linear regression on this data.<br>
#  ✔ Usually as the likes on a video increases the views on the video increases too  <br>

# %% [markdown]
# ## <a name="commti"></a>Most common words in video titles
# Let's see if there are some words that are used significantly in trending video titles. We will display the `25` most common words in all trending video titles

# %%
title_words = list(df_india["title"].apply(lambda x: x.split()))
title_words = [x for y in title_words for x in y]
Counter(title_words).most_common(25)
# Out:
# [('|', 173986),
#  ('-', 32709),
#  ('||', 20827),
#  ('#shorts', 10544),
#  ('2021', 10494),
#  ('&', 8653),
#  ('Song', 6787),
#  ('Episode', 6683),
#  ('New', 6495),
#  ('2', 5806),
#  ('The', 5549),
#  ('Punjabi', 5430),
#  ('2020', 5361),
#  ('Video', 5286),
#  ('Songs', 5038),
#  ('Official', 4898),
#  ('in', 4654),
#  ('Latest', 4524),
#  ('to', 4272),
#  ('Promo', 4047),
#  ('Video)', 3698),
#  ('TV', 3617),
#  ('Ka', 3564),
#  ('I', 3562),
#  ('Media', 3195)]

# %%
wc = wordcloud.WordCloud(width=1200, height=600, collocations=False, stopwords=None, background_color="white", colormap="tab20b").generate_from_frequencies(dict(Counter(title_words).most_common(150)))
# wc = wordcloud.WordCloud(width=1200, height=500, 
#                          collocations=False, background_color="white", 
#                          colormap="tab20b").generate(" ".join(title_words))
plt.figure(figsize=(15,10))
plt.imshow(wc, interpolation='bilinear')
_ = plt.axis("off")
_ = plt.title('25 MOST COMMON WORDS IN TITLE',fontsize=30)

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔ The most common words in the titles of videos that trend are 2021,#shorts,Song etc<br>
#  ✔ By using these words in title the chances of a video trending is higher <br>

# %% [markdown]
# ## <a name="chan"></a>Which channels have the largest number of trending videos?

# %%
cdf = df_india.groupby("channelTitle").size().reset_index(name="video_count") \
    .sort_values("video_count", ascending=False).head(20)
print(cdf)
# Out:
#                          channelTitle  video_count
# 3212                 Vijay Television         1670
# 615                         Colors TV         1115
# 3355                             ZEE5         1016
# 2664                         Sony SAB          945
# 2676               Sourav Joshi Vlogs          897
# 638                         Crazy XYZ          894
# 326                           Asianet          872
# 2866  Taarak Mehta Ka Ooltah Chashmah          715
# 2806                         T-Series          656
# 614                    Colors Rishtey          628
# 1565                MR. INDIAN HACKER          595
# 2760                           Sun TV          497
# 2707                         Star Maa          415
# 934                    Flowers Comedy          406
# 802                  Dushyant kukreja          401
# 936                      Flying Beast          390
# 2918                    Techno Gamerz          390
# 3383                           Zee TV          388
# 820                    ETV Jabardasth          385
# 2364                        SET India          385

# %%
fig, ax = plt.subplots(figsize=(8,8))
_ = sns.barplot(x="video_count", y="channelTitle", data=cdf,
                palette=sns.cubehelix_palette(n_colors=20, reverse=True), ax=ax)
_ = ax.set(xlabel="No. of videos", ylabel="Channel")
_ = plt.title('TOP 20 CHANNELS WITH TRENDING VIDEOS',fontsize=30)

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔ The channels having most trending videos are Vijay Television, Colors TV and Zee5<br>
#  ✔ Most channels are related to TV and movies channels or music channels with some education and vlogging channels.<br>

# %% [markdown]
# ## <a name="cat"></a>Which video category has the largest number of trending videos?

# %%
cdf = df_india["category_name"].value_counts().to_frame().reset_index()
cdf.rename(columns={"index": "category_name", "category_name": "No_of_videos"}, inplace=True)
print(cdf)
# Out:
#            category_name  No_of_videos
# 0          Entertainment         50295
# 1         People & Blogs         19166
# 2                  Music         18523
# 3                 Comedy         10440
# 4                 Gaming          6630
# 5   Science & Technology          4478
# 6          Howto & Style          4186
# 7        News & Politics          3995
# 8                 Sports          3785
# 9              Education          3028
# 10      Film & Animation          2804
# 11      Autos & Vehicles           758
# 12       Travel & Events           703
# 13        Pets & Animals            56

# %%
fig, ax = plt.subplots(figsize=(8,8))
_ = sns.barplot(x="category_name", y="No_of_videos", data=cdf, 
                palette=sns.cubehelix_palette(n_colors=16, reverse=True), ax=ax)
_ = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
_ = ax.set(xlabel="Category", ylabel="No. of videos")
_ = plt.title('TOP CATEGORIES HAVING MOST TRENDING VIDEOS',fontsize=30)

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔ The categories with the most trending videos is Entertainment by very large margin followed by People and Blogs, and Music.<br>
#  ✔ Publishing videos in these categories have higher chance of trending.<br>

# %% [markdown]
# ## <a name="pub"></a>Trending videos and their publishing time
# An example value of the `publish_time` column in our dataset is `2017-11-13T17:13:01.000Z`. And according to information on this page: https://www.w3.org/TR/NOTE-datetime, this means that the date of publishing the video is `2017-11-13` and the time is `17:13:01` in Coordinated Universal Time (UTC) time zone.
#
# Let's add two columns to represent the date and hour of publishing each video.

# %%
df_india["publishing_day"] = df_india["publishedAt"].apply(
    lambda x: datetime.datetime.strptime(x[:10], "%Y-%m-%d").date().strftime('%a'))
df_india["publishing_hour"] = df_india["publishedAt"].apply(lambda x: x[11:13]).astype('int')+5

# %%
cdf = df_india["publishing_day"].value_counts()\
        .to_frame().reset_index().rename(columns={"index": "publishing_day", "publishing_day": "No_of_videos"})
print(cdf)
# Out:
#   publishing_day  No_of_videos
# 0            Fri         20162
# 1            Wed         18783
# 2            Tue         18700
# 3            Thu         18695
# 4            Sat         17718
# 5            Mon         17489
# 6            Sun         17300

# %%
fig, ax = plt.subplots(figsize=(8,8))
_ = sns.barplot(x="publishing_day", y="No_of_videos", data=cdf, 
                palette=sns.color_palette(['#003f5c', '#374c80', '#7a5195', 
                                           '#bc5090', '#ef5675', '#ff764a', '#ffa600'], n_colors=7), ax=ax)
_ = ax.set(xlabel="Publishing Day", ylabel="No. of videos")
_ = plt.title('PUBLISHING DAY OF TRENDING VIDEOS',fontsize=30)

# %%
cdf = df_india["publishing_hour"].value_counts().to_frame().reset_index()\
        .rename(columns={"index": "publishing_hour", "publishing_hour": "No_of_videos"})
print(cdf)
# Out:
#     publishing_hour  No_of_videos
# 0                10         12415
# 1                17         11032
# 2                 9          9952
# 3                18          9621
# 4                11          9500
# 5                16          8838
# 6                19          8617
# 7                12          8513
# 8                13          7910
# 9                15          6746
# 10               20          6592
# 11               14          6208
# 12                8          6120
# 13                7          3613
# 14               21          3286
# 15               22          2283
# 16                6          1812
# 17               23          1709
# 18                5           960
# 19               24           936
# 20               25           623
# 21               26           541
# 22               27           511
# 23               28           509

# %%
fig, ax = plt.subplots(figsize=(8,8))
_ = sns.barplot(x="publishing_hour", y="No_of_videos", data=cdf, 
                palette=sns.cubehelix_palette(n_colors=24), ax=ax)
_ = ax.set(xlabel="Publishing Hour", ylabel="No. of videos")
_ = plt.title('PUBLISHING TIME OF TRENDING VIDEOS',fontsize=30)

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔ The best day to publish a video which can trend is Friday followed by Wednesday and Tuesday as they have the highest number of trending videos being published on that day.<br>
#  ✔ The best time of day to publish a video which can trend is morning 9am-12pm followed by 4-7pm during evening as they have the highest number of trending videos being published at that time of the day.<br>

# %% [markdown]
# ## <a name="commdis"></a>How many trending videos have their comments disabled?
# To know that, we use `comments_disabled` column

# %%
value_counts = df_india["comments_disabled"].value_counts().to_dict()
print(value_counts)
# Out:
# {False: 127754, True: 1093}

# %%
fig, ax = plt.subplots(figsize=(8,8))
_ = ax.pie(x=[value_counts[False], value_counts[True]], labels=['No', 'Yes'], 
           colors=['#003f5c', '#ffa600'], textprops={'color': '#040204'},autopct='%1.1f%%')
_ = ax.axis('equal')
_ = ax.set_title('Comments Disabled?',fontsize=30)

# %%
df_india["comments_disabled"].value_counts(normalize=True)*100
# Out:
# False   99.152
# True     0.848
# Name: comments_disabled, dtype: float64

# %% [markdown]
# ## <a name="ratdis"></a>How many trending videos have their ratings disabled?
# To know that, we use `ratings_disabled` column

# %%
value_counts = df_india["ratings_disabled"].value_counts().to_dict()
print(value_counts)
# Out:
# {False: 127772, True: 1075}

# %%
fig, ax = plt.subplots(figsize=(8,8))
_ = ax.pie([value_counts[False], value_counts[True]], labels=['No', 'Yes'], 
            colors=['#003f5c', '#ffa600'], textprops={'color': '#040204'},autopct='%1.1f%%')
_ = ax.axis('equal')
_ = ax.set_title('Ratings Disabled?',fontsize=30)

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔ About 99% of trending videos have their comments enabled.<br>
#  ✔ About 99% of trending videos have their ratings enabled.<br>
#  ✔ Videos having comments and ratings(likes/dislikes) enabled have higher chance of trending.<br>

# %% [markdown]
# <h1 style="font-family:COMIC SANS ;text-align:left;background-color:salmon"><b>📄 Machine Learning📄</b></h1>

# %% [markdown]
# ## Predicting views of a video based on likes

# %%
#Importing the regression models from sklearn
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Extracting the features and target variable.
X = np.array(df_india['likes']).reshape(-1, 1)
y = np.array(df_india['view_count']).reshape(-1, 1)
print(X,y)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40)
# Out:
# [[224925]
#  [655450]
#  [296533]
#  ...
#  [  1524]
#  [ 97307]
#  [ 26985]] [[ 9885899]
#  [11308046]
#  [ 9140911]
#  ...
#  [  295374]
#  [ 1079878]
#  [ 1065703]]

# %% [markdown]
# # Linear Regression model to predict views on the basis of likes

# %%
regr = LinearRegression()
 
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.6788188977798437

# %% [markdown]
# # Random Forest Regressor to predict views on the basis of likes

# %%
from sklearn.ensemble import RandomForestRegressor
 
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 300, random_state = 0)
 
# fit the regressor with x and y data
regressor.fit(X_train, y_train) 
print(regressor.score(X_test, y_test))
# Out:
# 0.5327897683664697

# %% [markdown]
# # Support Vector Regressor to predict views on the basis of likes

# %%
from sklearn.preprocessing import StandardScaler
scale_X = StandardScaler()
scale_y = StandardScaler()

X = scale_X.fit_transform(X)
y = scale_y.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40)

# %%
from sklearn.svm import SVR

svr_regressor = SVR(kernel='rbf', gamma='auto')
svr_regressor.fit(X_train, y_train)
# Out:
# SVR(gamma='auto')

# %%
print(svr_regressor.score(X_train, y_train))
# Out:
# 0.6146093402696349

# %% [markdown]
# # Comparison of the accuracy of the different regression models

# %%
models= ['Linear Regression','Random Forest Regressor','Support Vector Regressor']
accuracy_scores=[67.5,54.8,63.7]
df_accuracy  = pd.DataFrame()
df_accuracy["Model"] = models
df_accuracy["Accuracy %"] = accuracy_scores
df_accuracy
# Out:
#                       Model  Accuracy %
# 0         Linear Regression      67.500
# 1   Random Forest Regressor      54.800
# 2  Support Vector Regressor      63.700

# %%
plt.bar(df_accuracy['Model'], df_accuracy['Accuracy %'],color=['black', 'red', 'green'])
plt.xlabel('Model Used')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy of Different Regression Models',fontsize=30)
plt.rcParams["figure.figsize"] = (15,8) 
plt.show()

# %% [markdown]
# <div class ="alert alert-block alert-info">🦉<b>Observations</b>🦉<br>
#  ✔ We can predict the views of a video on the basis of its likes by using ML regression models like Linear Regression, Support Vector Regressor(SVR), Random Forest Regressor etc.<br>
#  ✔ On this dataset Linear Regression gave the best testing accuracy of 67.5% followed by SVR at 63.7% and Random Forest Regressor at 54.8%.<br>

# %% [markdown]
# # Conclusions

# %% [markdown]
# We have drawn many interesting inferences from the dataset Youtube trending videos; here’s a summary of the few of them:
#
# - The likes and views of a video are the most correlated features of a trending video and can be used to train a ML regression model to predict views of a video.
#
# - The most common words in the title of trending videos are 2021, #shorts, Song etc. By using these words in the title of video it gives higher chance of getting trending.
#
# - The channels with the most trending videos is Vijay Television followed by Colors TV and Zee5.
#
# - The categories with the most trending videos is Entertainment by very large margin followed by People and Blogs, and Music.
#
# - The best day to publish a video which can trend is Friday followed by Wednesday and Tuesday as they have the highest number of trending videos being published on that day.
#
# - The best time of day to publish a video which can trend is morning 9am-12pm followed by 4-7pm during evening as they have the highest number of trending videos being published at that time of the day.
#
# - About 99% of trending videos have their comments enabled.
#
# - About 99% of trending videos have their ratings enabled
#
# - We can predict the views of a video on the basis of its likes by using ML regression models like Linear Regression, Support Vector Regressor(SVR), Random Forest Regressor etc. On this dataset Linear Regression gave the best testing accuracy of 67.5% followed by SVR at 63.7% and Random Forest Regressor at 54.8%.
